# %%
from tensorflow import keras
import numpy as np

# %%
model=keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
model.compile(optimizer="sgd",loss="mse")
# Out:
# WARNING:tensorflow:From C:\Users\Berk\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
xs=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys=np.array([-3.0,-1.0,1.1,3.0,5.0,7.0],dtype=float)

# %%
model.fit(xs,ys,epochs=100)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 37ms/sample - loss: 21.5880
# Epoch 2/100
# 6/6 [==============================] - 0s 333us/sample - loss: 17.2518
# Epoch 3/100
# 6/6 [==============================] - 0s 339us/sample - loss: 13.8347
# Epoch 4/100
# 6/6 [==============================] - 0s 333us/sample - loss: 11.1410
# Epoch 5/100
# 6/6 [==============================] - 0s 332us/sample - loss: 9.0165
# Epoch 6/100
# 6/6 [==============================] - 0s 333us/sample - loss: 7.3398
# Epoch 7/100
# 6/6 [==============================] - 0s 166us/sample - loss: 6.0156
# Epoch 8/100
# 6/6 [==============================] - 0s 330us/sample - loss: 4.9689
# Epoch 9/100
# 6/6 [==============================] - 0s 332us/sample - loss: 4.1406
# Epoch 10/100
# 6/6 [==============================] - 0s 500us/sample - loss: 3.4841
# Epoch 11/100
# 6/6 [==============================] - 0s 498us/sample - loss: 2.9630
# Epoch 12/100
# 6/6 [==============================] - 0s 332us/sample - loss: 2.5484
# Epoch 13/100
# 6/6 [==============================] - 0s 499us/sample - loss: 2.2178
# Epoch 14/100
# 6/6 [==============================] - 0s 665us/sample - loss: 1.9534
# Epoch 15/100
# 6/6 [==============================] - 0s 166us/sample - loss: 1.7410
# Epoch 16/100
# 6/6 [==============================] - 0s 499us/sample - loss: 1.5698
# Epoch 17/100
# 6/6 [==============================] - 0s 332us/sample - loss: 1.4310
# Epoch 18/100
# 6/6 [==============================] - 0s 332us/sample - loss: 1.3177
# Epoch 19/100
# 6/6 [==============================] - 0s 496us/sample - loss: 1.2247
# Epoch 20/100
# 6/6 [==============================] - 0s 499us/sample - loss: 1.1476
# Epoch 21/100
# 6/6 [==============================] - 0s 665us/sample - loss: 1.0832
# Epoch 22/100
# 6/6 [==============================] - 0s 499us/sample - loss: 1.0289
# Epoch 23/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.9825
# Epoch 24/100
# 6/6 [==============================] - 0s 331us/sample - loss: 0.9424
# Epoch 25/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.9075
# Epoch 26/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.8765
# Epoch 27/100
# 6/6 [==============================] - 0s 330us/sample - loss: 0.8489
# Epoch 28/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.8238
# Epoch 29/100
# 6/6 [==============================] - 0s 666us/sample - loss: 0.8009
# Epoch 30/100
# 6/6 [==============================] - 0s 167us/sample - loss: 0.7798
# Epoch 31/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.7601
# Epoch 32/100
# 6/6 [==============================] - 0s 496us/sample - loss: 0.7416
# Epoch 33/100
# 6/6 [==============================] - 0s 164us/sample - loss: 0.7241
# Epoch 34/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.7074
# Epoch 35/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.6915
# Epoch 36/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.6762
# Epoch 37/100
# 6/6 [==============================] - 0s 331us/sample - loss: 0.6615
# Epoch 38/100
# 6/6 [==============================] - 0s 666us/sample - loss: 0.6472
# Epoch 39/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.6334
# Epoch 40/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.6200
# Epoch 41/100
# 6/6 [==============================] - 0s 165us/sample - loss: 0.6070
# Epoch 42/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.5943
# Epoch 43/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.5819
# Epoch 44/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.5698
# Epoch 45/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.5580
# Epoch 46/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.5464
# Epoch 47/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.5352
# Epoch 48/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.5241
# Epoch 49/100
# 6/6 [==============================] - 0s 665us/sample - loss: 0.5133
# Epoch 50/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.5028
# Epoch 51/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.4925
# Epoch 52/100
# 6/6 [==============================] - 0s 663us/sample - loss: 0.4824
# Epoch 53/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.4725
# Epoch 54/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.4628
# Epoch 55/100
# 6/6 [==============================] - 0s 498us/sample - loss: 0.4533
# Epoch 56/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.4440
# Epoch 57/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.4349
# Epoch 58/100
# 6/6 [==============================] - 0s 665us/sample - loss: 0.4260
# Epoch 59/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.4172
# Epoch 60/100
# 6/6 [==============================] - 0s 167us/sample - loss: 0.4087
# Epoch 61/100
# 6/6 [==============================] - 0s 665us/sample - loss: 0.4003
# Epoch 62/100
# 6/6 [==============================] - 0s 331us/sample - loss: 0.3921
# Epoch 63/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.3841
# Epoch 64/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.3762
# Epoch 65/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.3685
# Epoch 66/100
# 6/6 [==============================] - 0s 168us/sample - loss: 0.3610
# Epoch 67/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.3536
# Epoch 68/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.3464
# Epoch 69/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.3393
# Epoch 70/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.3323
# Epoch 71/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.3255
# Epoch 72/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.3189
# Epoch 73/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.3124
# Epoch 74/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.3060
# Epoch 75/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.2997
# Epoch 76/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.2936
# Epoch 77/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.2876
# Epoch 78/100
# 6/6 [==============================] - 0s 830us/sample - loss: 0.2817
# Epoch 79/100
# 6/6 [==============================] - 0s 331us/sample - loss: 0.2760
# Epoch 80/100
# 6/6 [==============================] - 0s 499us/sample - loss: 0.2703
# Epoch 81/100
# 6/6 [==============================] - 0s 497us/sample - loss: 0.2648
# Epoch 82/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.2594
# Epoch 83/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.2541
# Epoch 84/100
# 6/6 [==============================] - 0s 497us/sample - loss: 0.2489
# Epoch 85/100
# 6/6 [==============================] - 0s 331us/sample - loss: 0.2438
# Epoch 86/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.2388
# Epoch 87/100
# 6/6 [==============================] - 0s 166us/sample - loss: 0.2339
# Epoch 88/100
# 6/6 [==============================] - 0s 831us/sample - loss: 0.2292
# Epoch 89/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.2245
# Epoch 90/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.2199
# Epoch 91/100
# 6/6 [==============================] - 0s 667us/sample - loss: 0.2154
# Epoch 92/100
# 6/6 [==============================] - 0s 330us/sample - loss: 0.2110
# Epoch 93/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.2067
# Epoch 94/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.2025
# Epoch 95/100
# 6/6 [==============================] - 0s 1000us/sample - loss: 0.1984
# Epoch 96/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.1943
# Epoch 97/100
# 6/6 [==============================] - 0s 333us/sample - loss: 0.1904
# Epoch 98/100
# 6/6 [==============================] - 0s 661us/sample - loss: 0.1865
# Epoch 99/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.1827
# Epoch 100/100
# 6/6 [==============================] - 0s 332us/sample - loss: 0.1789

# %%
model.predict([10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-90cdcb84a2c6> in <module>
# ----> 1 model.predict(10.0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1058     # generate symbolic tensors).
#    1059     x, _, _ = self._standardize_user_data(
# -> 1060         x, check_steps=True, steps_name='steps', steps=steps)
#    1061
#    1062     if self.run_eagerly:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2649           feed_input_shapes,
#    2650           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2651           exception_prefix='input')
#    2652
#    2653     if y is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     332   if shapes is not None:
#     333     data = [
# --> 334         standardize_single_array(x, shape) for (x, shape) in zip(data, shapes)
#     335     ]
#     336   else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in <listcomp>(.0)
#     332   if shapes is not None:
#     333     data = [
# --> 334         standardize_single_array(x, shape) for (x, shape) in zip(data, shapes)
#     335     ]
#     336   else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in standardize_single_array(x, expected_shape)
#     263     return None
#     264
# --> 265   if (x.shape is not None and len(x.shape) == 1 and
#     266       (expected_shape is None or len(expected_shape) != 1)):
#     267     if tensor_util.is_tensor(x):
#
# AttributeError: 'float' object has no attribute 'shape'
